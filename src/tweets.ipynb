# %% [markdown]
# ### Imports

# %%
## 0.A Import libraries
import os

# dates
from datetime import datetime

# data handling
import numpy as np
import pandas as pd

# Data viz
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
## 0.B Import functions
from utils.custom_functions import generate_descriptive_analysis
from utils.custom_functions import label_sent_analysis, label_political_entity

# %%
## O.C Arguments Paths
tweets_filename = r"01.Tweets.csv"
retweets_filename = r"02.Retweets.csv"
users_filename = r"03.Users.csv"

gravity_filename = r"gravity_1995_2014.dta"

trade_filenae = r"TradeData.csv"

gdp_filename_1 = r"gdp_1.csv"
gdp_filename_2 = r"gdp_2.csv"

population_filename = r"pop.csv"

country_code_filename = r"iso-country-codes.csv"

# %%
folder_path = os.path.dirname(os.getcwd())
path_to_data = os.path.join(folder_path,'data')

# %% [markdown]
# ## 1. Data

# %%
## 1. Import data
users = pd.read_csv(os.path.join(path_to_data,users_filename),
    dtype = {'user_id': 'int64'}
)
users = users.drop(columns=['Unnamed: 0'])
# generate_descriptive_analysis(df = users, output_filename="users_descript") # Comment out 

# Let's have a look
users.head()
# Out:
#      user_id                                                bio bio_lang  \
# 0  116680494  #news upate #uk news # austalia  china # japan...    en 39
# 1  172576367  Option Trader | Fundamental and Indicasies | M...    en 42
# 2  154226261  BBC Science and Tech Correspondent, based in s...    en 87
# 3   61733677                              Curious about finance    en 86
# 4   87775422  Start a conversation as we share news and anal...    en 95
#
#                                               bio_en  verified  \
# 0  #news upate #uk news # austalia  china # japan...     False
# 1  Option Trader | Fundamental and Indicasies | M...     False
# 2  BBC Science and Tech Correspondent, based in s...     False
# 3                              Curious about finance     False
# 4  Start a conversation as we share news and anal...      True
#
#                       political political_lang                  political_en  \
# 0                           NaN            NaN                           NaN
# 1                           NaN            NaN                           NaN
# 2                           NaN            NaN                           NaN
# 3                           NaN            NaN                           NaN
# 4  China state-affiliated media          en 85  China state-affiliated media
#
#                  date_joined  \
# 0  2010-02-23 08:03:27+00:00
# 1  2010-07-30 01:45:04+00:00
# 2  2010-06-10 18:10:08+00:00
# 3  2009-07-31 09:23:42+00:00
# 4  2009-11-05 20:30:10+00:00
#
#                                        profile_image  \
# 0  https://pbs.twimg.com/profile_images/713321288...
# 1  https://pbs.twimg.com/profile_images/109116695...
# 2  https://pbs.twimg.com/profile_images/100002619...
# 3  https://abs.twimg.com/sticky/default_profile_i...
# 4  https://pbs.twimg.com/profile_images/133814999...
#
#                                       profile_banner       profile_location  \
# 0                                                NaN    The World in Tweets
# 1                                                NaN       Bali - Indonesia
# 2  https://pbs.twimg.com/profile_banners/15422626...     Cambridge, England
# 3                                                NaN  Ulaanbaatar, Mongolia
# 4  https://pbs.twimg.com/profile_banners/87775422...         Beijing, China
#
#   profile_location_lang profile_location_country_en  num_tweets  media_count  \
# 0                 en 75                         NaN      220821          0.0
# 1                 id 50                   Indonesia      226257          0.0
# 2                 en 30              United Kingdom       12505        830.0
# 3                 en 36   THE MOST KNOW ᠮᠤᠩᠭᠤᠯ ᠤᠯᠤᠰ       18502          0.0
# 4                 en 71                       China      161125      84967.0
#
#    followers  following
# 0        667         11
# 1         28         21
# 2       7948       1417
# 3        322          4
# 4    4261985        577

# %%
# a. Top Ten countries represented?
users.profile_location_country_en.value_counts().sort_values()[-10:]
# Out:
# France             3821
# Luzon              4424
# China              4718
# Canada             5839
# Indonesia          5977
# Australia          8966
# United Kingdom    12082
# Pakistan          12245
# India             16375
# United States     37778
# Name: profile_location_country_en, dtype: int64

# %% [markdown]
# Tweets data

# %%
## 1. Import data
tweets = pd.read_csv(os.path.join(path_to_data, tweets_filename),
    dtype = {'user_id': 'int64'},
    parse_dates=['timestamp']
)
tweets = tweets.drop(columns=['Unnamed: 0'])

# generate_descriptive_analysis(df = tweets, output_filename="tweets_descript") # Comment out 

# Let's have a look
tweets.head()
# Out:
# /var/folders/dk/28gb2q9512d3w1nv9b59mmz40000gn/T/ipykernel_6157/1285574248.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets = pd.read_csv(os.path.join(path_to_data, tweets_filename),
#      user_id                 timestamp            tweet_id  \
# 0  116680494 2013-09-03 02:22:09+00:00  374718928682885121
# 1  172576367 2013-09-03 02:22:11+00:00  374718937889402880
# 2  154226261 2013-09-03 10:11:50+00:00  374837127873175553
# 3   61733677 2013-09-03 11:33:26+00:00  374857665735704576
# 4   87775422 2013-09-03 20:10:51+00:00  374987876737765376
#
#    sentiment_polarity text_lang_ft  \
# 0              0.2732        en 88
# 1              0.2732        en 84
# 2              0.0000        en 47
# 3              0.2732        en 65
# 4              0.0000        en 56
#
#                                      text_normalized  \
# 0  ['nation', 'agree', 'build', 'new', 'silk', 'r...
# 1  ['nation', 'agree', 'build', 'new', 'silk', 'r...
# 2  ['high', 'speed', 'rail', 'china', 'new', 'sil...
# 3  ['nation', 'agree', 'build', 'new', 'silk', 'r...
# 4  ['china', 'kazakhstan', 'tajikistan', 'russia'...
#
#                                                links hashtag hashtag_lang  \
# 0                              http://bit.ly/17lyTPM     NaN          NaN
# 1                              http://bit.ly/17lySv6     NaN          NaN
# 2                                                NaN     NaN          NaN
# 3                                                NaN     NaN          NaN
# 4  http://usa.chinadaily.com.cn/epaper/2013-09/03...   China        en 50
#
#   hashtag_en  ... GIF_url likes retweets replies reply_to_user  \
# 0        NaN  ...     NaN     0        0       0           NaN
# 1        NaN  ...     NaN     0        0       0           NaN
# 2        NaN  ...     NaN     1        0       0           NaN
# 3        NaN  ...     NaN     0        0       0           NaN
# 4      China  ...     NaN     2        6       0           NaN
#
#    mentioned_users  quoted_tweet  quoted_by_count credibility  \
# 0              NaN           NaN                0         1.0
# 1              NaN           NaN                0         1.0
# 2         83521919           NaN                0         NaN
# 3              NaN           NaN                0         NaN
# 4              NaN           NaN                0         0.0
#
#            tweet_source
# 0           twitterfeed
# 1           twitterfeed
# 2  Twitter for Websites
# 3    Twitter Web Client
# 4             Hootsuite
#
# [5 rows x 24 columns]

# %%
tweets['year'] = pd.DatetimeIndex(tweets['timestamp']).year

# %%
tweets.year.value_counts().sort_values(ascending=True)
# Out:
# 2013      1564
# 2014      8889
# 2015     25652
# 2016     32434
# 2021     57982
# 2020     69133
# 2018     89069
# 2017    107923
# 2019    108064
# Name: year, dtype: int64

# %% [markdown]
# Retweets data

# %%
## 1. Import data
retweets = pd.read_csv(os.path.join(path_to_data, retweets_filename),
    dtype = {'target': 'int64'}
)
retweets = retweets.drop(columns=['Unnamed: 0'])

# Let's have a look
retweets.head()
# Out:
#        source      target                  timestamp      tweet_id
# 0  87775422.0   137271696  2013-09-03 21:09:47+00:00  3.749879e+17
# 1  87775422.0   338426531  2013-09-03 20:39:47+00:00  3.749879e+17
# 2  87775422.0  1483526748  2013-09-03 20:35:37+00:00  3.749879e+17
# 3  87775422.0  1443874496  2013-09-03 20:33:38+00:00  3.749879e+17
# 4  87775422.0  1613544854  2013-09-03 20:13:25+00:00  3.749879e+17

# %% [markdown]
# ## Join Twitter datasets

# %%
tweets.columns
# Out:
# Index(['user_id', 'timestamp', 'tweet_id', 'sentiment_polarity',
#        'text_lang_ft', 'text_normalized', 'links', 'hashtag', 'hashtag_lang',
#        'hashtag_en', 'cashtag', 'media', 'image_url', 'video_url', 'GIF_url',
#        'likes', 'retweets', 'replies', 'reply_to_user', 'mentioned_users',
#        'quoted_tweet', 'quoted_by_count', 'credibility', 'tweet_source',
#        'year'],
#       dtype='object')

# %%
tweets['user_id'] = pd.to_numeric(tweets['user_id'])
users['user_id'] = pd.to_numeric(users['user_id'])
users[['user_id','profile_location_country_en', 'political_en']].head()
tweets = tweets[['tweet_id','user_id', 'sentiment_polarity', 'likes', 'retweets', 'year']]

# %% [markdown]
# I want the yealry number of tweets about the project by country, the number of tweets positive, the number of tweets negative, the number of tweets made by a political affiliate.

# %%
# 1. Joining twitter dataset with the users
merged_tweets = tweets.merge(users[['user_id','profile_location_country_en', 'political_en']], on='user_id', how='right')

# %%
merged_tweets['tweet_id'].count()
# Out:
# 118413525

# %%
len(merged_tweets['tweet_id'].unique())
# Out:
# 500701

# %%
merged_tweets.head()
# Out:
#        tweet_id    user_id  sentiment_polarity  likes  retweets    year  \
# 0  3.747189e+17  116680494              0.2732    0.0       0.0  2013.0
# 1  3.762299e+17  116680494              0.0000    0.0       0.0  2013.0
# 2  4.240629e+17  116680494              0.3818    0.0       0.0  2014.0
# 3  4.491235e+17  116680494              0.5719    0.0       0.0  2014.0
# 4  3.747189e+17  172576367              0.2732    0.0       0.0  2013.0
#
#   profile_location_country_en political_en
# 0                         NaN          NaN
# 1                         NaN          NaN
# 2                         NaN          NaN
# 3                         NaN          NaN
# 4                   Indonesia          NaN

# %%
merged_tweets = merged_tweets.dropna(subset='profile_location_country_en')
merged_tweets.head()
# Out:
#        tweet_id    user_id  sentiment_polarity  likes  retweets    year  \
# 4  3.747189e+17  172576367              0.2732    0.0       0.0  2013.0
# 5  3.762299e+17  172576367              0.0000    0.0       0.0  2013.0
# 6  4.240629e+17  172576367              0.3818    0.0       0.0  2014.0
# 7  4.491235e+17  172576367              0.5719    0.0       0.0  2014.0
# 8  3.748371e+17  154226261              0.0000    1.0       0.0  2013.0
#
#   profile_location_country_en political_en
# 4                   Indonesia          NaN
# 5                   Indonesia          NaN
# 6                   Indonesia          NaN
# 7                   Indonesia          NaN
# 8              United Kingdom          NaN

# %%
merged_tweets['tweet_id'].count()
# Out:
# 43387003

# %%
len(merged_tweets['tweet_id'].unique())
# Out:
# 348031

# %%
merged_tweets = merged_tweets.drop_duplicates(subset = 'tweet_id')

# %%
merged_tweets['tweet_id'].count()
# Out:
# 348030

# %%
tweets = merged_tweets

# %%
tweets.head()
# Out:
#        tweet_id    user_id  sentiment_polarity  likes  retweets    year  \
# 4  3.747189e+17  172576367              0.2732    0.0       0.0  2013.0
# 5  3.762299e+17  172576367              0.0000    0.0       0.0  2013.0
# 6  4.240629e+17  172576367              0.3818    0.0       0.0  2014.0
# 7  4.491235e+17  172576367              0.5719    0.0       0.0  2014.0
# 8  3.748371e+17  154226261              0.0000    1.0       0.0  2013.0
#
#   profile_location_country_en political_en
# 4                   Indonesia          NaN
# 5                   Indonesia          NaN
# 6                   Indonesia          NaN
# 7                   Indonesia          NaN
# 8              United Kingdom          NaN

# %% [markdown]
# ## Creating features

# %%
# if positive sentiment analysis, create a dummy equal to one, otherwise 0.
tweets["tweets_positive_sent"] = tweets["sentiment_polarity"].apply(label_sent_analysis)
tweets["tweets_political"] = tweets["political_en"].apply(label_political_entity)

# %%
tweets["tweets_political"].sum()
# Out:
# 233398

# %%
tweets.political_en.replace('NaN', np.nan).dropna()
# Out:
# 6                       China state-affiliated media
# 7                       China state-affiliated media
# 8                       China state-affiliated media
# 9                       China state-affiliated media
# 10                      China state-affiliated media
#                              ...
# 335617    Media affiliated to the Chinese government
# 338230                  State-affiliated media China
# 344096                  China state-affiliated media
# 344097                  China state-affiliated media
# 346629                  China state-affiliated media
# Name: political_en, Length: 10329, dtype: object

# %% [markdown]
# I will work on a yearly level.
# I want the aggregate count of tweets, their average sentiment polarity, the aggregate level of retweets, the average of retweets by month and by country

# %%
# Let's reduce dataset dimension and add a country code
columns= ["year","profile_location_country_en","tweets_positive_sent", "tweets_political",'likes','retweets']
tweets = tweets[columns]

# %%
country_code = pd.read_csv(os.path.join(path_to_data, country_code_filename))
country_code = country_code.rename(columns = {"English short name lower case": "country"})
tweets = pd.merge(tweets, country_code, left_on='profile_location_country_en',right_on='country', how='left')

# %%
tweets.head()
# Out:
#        tweet_id    user_id  sentiment_polarity  likes  retweets    year  \
# 0  3.747189e+17  172576367              0.2732    0.0       0.0  2013.0
# 1  3.762299e+17  172576367              0.0000    0.0       0.0  2013.0
# 2  4.240629e+17  172576367              0.3818    0.0       0.0  2014.0
# 3  4.491235e+17  172576367              0.5719    0.0       0.0  2014.0
# 4  3.748371e+17  154226261              0.0000    1.0       0.0  2013.0
#
#   profile_location_country_en political_en  tweets_positive_sent  \
# 0                   Indonesia          NaN                     1
# 1                   Indonesia          NaN                     0
# 2                   Indonesia          NaN                     1
# 3                   Indonesia          NaN                     1
# 4              United Kingdom          NaN                     0
#
#    tweets_political         country Alpha-2 code Alpha-3 code  Numeric code  \
# 0                 1       Indonesia           ID          IDN         360.0
# 1                 1       Indonesia           ID          IDN         360.0
# 2                 1       Indonesia           ID          IDN         360.0
# 3                 1       Indonesia           ID          IDN         360.0
# 4                 1  United Kingdom           GB          GBR         826.0
#
#       ISO 3166-2
# 0  ISO 3166-2:ID
# 1  ISO 3166-2:ID
# 2  ISO 3166-2:ID
# 3  ISO 3166-2:ID
# 4  ISO 3166-2:GB

# %%
tweets['Key'] = tweets['Alpha-3 code'] + '_' + tweets['year'].astype(str)

# %%
tweets.to_csv('junk_tweets_and_users.csv')

# %%
len(tweets['country'].unique())
# Out:
# 141

# %%
tweets = pd.read_csv('junk_tweets_and_users.csv')

# %%
tweets.head()
# Out:
#    Unnamed: 0      tweet_id    user_id  sentiment_polarity  likes  retweets  \
# 0           0  3.747189e+17  172576367              0.2732    0.0       0.0
# 1           1  3.762299e+17  172576367              0.0000    0.0       0.0
# 2           2  4.240629e+17  172576367              0.3818    0.0       0.0
# 3           3  4.491235e+17  172576367              0.5719    0.0       0.0
# 4           4  3.748371e+17  154226261              0.0000    1.0       0.0
#
#      year profile_location_country_en political_en  tweets_positive_sent  \
# 0  2013.0                   Indonesia          NaN                     1
# 1  2013.0                   Indonesia          NaN                     0
# 2  2014.0                   Indonesia          NaN                     1
# 3  2014.0                   Indonesia          NaN                     1
# 4  2013.0              United Kingdom          NaN                     0
#
#    tweets_political         country Alpha-2 code Alpha-3 code  Numeric code  \
# 0                 1       Indonesia           ID          IDN         360.0
# 1                 1       Indonesia           ID          IDN         360.0
# 2                 1       Indonesia           ID          IDN         360.0
# 3                 1       Indonesia           ID          IDN         360.0
# 4                 1  United Kingdom           GB          GBR         826.0
#
#       ISO 3166-2         Key
# 0  ISO 3166-2:ID  IDN_2013.0
# 1  ISO 3166-2:ID  IDN_2013.0
# 2  ISO 3166-2:ID  IDN_2014.0
# 3  ISO 3166-2:ID  IDN_2014.0
# 4  ISO 3166-2:GB  GBR_2013.0

# %%
tweets = tweets.dropna(subset=['country'])

# %%
columns_stats = ["tweets_positive_sent", "tweets_political",'likes','retweets']
grouped = tweets.groupby(['country','year'])["tweets_positive_sent", "tweets_political",'likes','retweets'].agg(['sum','count']).reset_index()
grouped.head()
# Out:
# /var/folders/dk/28gb2q9512d3w1nv9b59mmz40000gn/T/ipykernel_6157/115749463.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped = tweets.groupby(['country','year'])["tweets_positive_sent", "tweets_political",'likes','retweets'].agg(['sum','count']).reset_index()
#        country    year tweets_positive_sent       tweets_political        \
#                                         sum count              sum count
# 0  Afghanistan  2013.0                    2     4                4     4
# 1  Afghanistan  2014.0                    8    18               18    18
# 2  Afghanistan  2015.0                    6    11               11    11
# 3  Afghanistan  2016.0                   17    44               44    44
# 4  Afghanistan  2017.0                   13    54               54    54
#
#    likes       retweets
#      sum count      sum count
# 0    0.0     4      6.0     4
# 1   10.0    18     15.0    18
# 2    1.0    11      0.0    11
# 3  271.0    44     84.0    44
# 4  266.0    54     89.0    54

# %%
country_code = pd.read_csv(os.path.join(path_to_data, country_code_filename))
country_code = country_code.rename(columns = {"English short name lower case": "country"})

# %%
country_code
# Out:
#                country Alpha-2 code Alpha-3 code  Numeric code     ISO 3166-2
# 0          Afghanistan           AF          AFG             4  ISO 3166-2:AF
# 1        Åland Islands           AX          ALA           248  ISO 3166-2:AX
# 2              Albania           AL          ALB             8  ISO 3166-2:AL
# 3              Algeria           DZ          DZA            12  ISO 3166-2:DZ
# 4       American Samoa           AS          ASM            16  ISO 3166-2:AS
# ..                 ...          ...          ...           ...            ...
# 241  Wallis and Futuna           WF          WLF           876  ISO 3166-2:WF
# 242     Western Sahara           EH          ESH           732  ISO 3166-2:EH
# 243              Yemen           YE          YEM           887  ISO 3166-2:YE
# 244             Zambia           ZM          ZMB           894  ISO 3166-2:ZM
# 245           Zimbabwe           ZW          ZWE           716  ISO 3166-2:ZW
#
# [246 rows x 5 columns]

# %%
grouped = pd.merge(grouped,country_code[['country','Alpha-3 code']], left_on='country', right_on='country', how = 'left')
# Out:
# /var/folders/dk/28gb2q9512d3w1nv9b59mmz40000gn/T/ipykernel_6157/317920944.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   grouped = pd.merge(grouped,country_code[['country','Alpha-3 code']], left_on='country', right_on='country', how = 'left')

# %%
grouped_refactored.to_csv("groupedv2_refactored.csv")

# %%
grouped_refactored = pd.read_csv('groupedv2_refactored.csv', 
sep = ';',
dtype={'Year':int}
)
grouped_refactored.drop('Unnamed: 0', axis=1, inplace = True)
grouped_refactored.rename(columns = {'Year':'year'}, inplace=True)
grouped_refactored.head()
# Out:
#        country      Country  year  sum_pos_tweets  count_tweets  \
# 0  Afghanistan  Afghanistan  2013               2             4
# 1  Afghanistan  Afghanistan  2014               8            18
# 2  Afghanistan  Afghanistan  2015               6            11
# 3  Afghanistan  Afghanistan  2016              17            44
# 4  Afghanistan  Afghanistan  2017              13            54
#
#    sum_political_tweets  sum_likes  sum_retweeets Alpha-3 code
# 0                     4        0.0            6.0          AFG
# 1                    18       10.0           15.0          AFG
# 2                    11        1.0            0.0          AFG
# 3                    44      271.0           84.0          AFG
# 4                    54      266.0           89.0          AFG

# %%
grouped_refactored['Key'] = grouped_refactored['Alpha-3 code'] + '_' + grouped_refactored['year'].astype(str)

# %%
grouped_refactored.head()
# Out:
#        country      Country  year  sum_pos_tweets  count_tweets  \
# 0  Afghanistan  Afghanistan  2013               2             4
# 1  Afghanistan  Afghanistan  2014               8            18
# 2  Afghanistan  Afghanistan  2015               6            11
# 3  Afghanistan  Afghanistan  2016              17            44
# 4  Afghanistan  Afghanistan  2017              13            54
#
#    sum_political_tweets  sum_likes  sum_retweeets Alpha-3 code       Key
# 0                     4        0.0            6.0          AFG  AFG_2013
# 1                    18       10.0           15.0          AFG  AFG_2014
# 2                    11        1.0            0.0          AFG  AFG_2015
# 3                    44      271.0           84.0          AFG  AFG_2016
# 4                    54      266.0           89.0          AFG  AFG_2017

# %%
grouped.columns
# Out:
# Index([                        'country',                   ('country', ''),
#                             ('year', ''),   ('tweets_positive_sent', 'sum'),
#        ('tweets_positive_sent', 'count'),       ('tweets_political', 'sum'),
#            ('tweets_political', 'count'),                  ('likes', 'sum'),
#                       ('likes', 'count'),               ('retweets', 'sum'),
#                    ('retweets', 'count'),                    'Alpha-3 code'],
#       dtype='object')

# %%
grouped.rename(columns={"('year', '')":'year'})
# Out:
#           country  (country, )  (year, )  (tweets_positive_sent, sum)  \
# 0     Afghanistan  Afghanistan      2013                            2
# 1     Afghanistan  Afghanistan      2014                            8
# 2     Afghanistan  Afghanistan      2015                            6
# 3     Afghanistan  Afghanistan      2016                          142
# 4     Afghanistan  Afghanistan      2017                         1923
# ...           ...          ...       ...                          ...
# 1066     Zimbabwe     Zimbabwe      2017                         1143
# 1067     Zimbabwe     Zimbabwe      2018                         4010
# 1068     Zimbabwe     Zimbabwe      2019                        13077
# 1069     Zimbabwe     Zimbabwe      2020                         7665
# 1070     Zimbabwe     Zimbabwe      2021                         7769
#
#       (tweets_positive_sent, count)  (tweets_political, sum)  \
# 0                                 4                        4
# 1                                18                       18
# 2                                11                       11
# 3                               468                      468
# 4                              4956                     4956
# ...                             ...                      ...
# 1066                           3001                     3001
# 1067                           9240                     9240
# 1068                          28903                    28903
# 1069                          17976                    17976
# 1070                          17217                    17217
#
#       (tweets_political, count)  (likes, sum)  (likes, count)  \
# 0                             4             0               4
# 1                            18            10              18
# 2                            11             1              11
# 3                           468           459             468
# 4                          4956          6618            4956
# ...                         ...           ...             ...
# 1066                       3001          2491            3001
# 1067                       9240         19549            9240
# 1068                      28903         62871           28903
# 1069                      17976         55590           17976
# 1070                      17217         89025           17217
#
#       (retweets, sum)  (retweets, count) Alpha-3 code
# 0                   6                  4          AFG
# 1                  15                 18          AFG
# 2                   0                 11          AFG
# 3                 194                468          AFG
# 4                6953               4956          AFG
# ...               ...                ...          ...
# 1066             2008               3001          ZWE
# 1067             8933               9240          ZWE
# 1068            30636              28903          ZWE
# 1069            18021              17976          ZWE
# 1070            27043              17217          ZWE
#
# [1071 rows x 12 columns]

# %%
grouped.reset_index().columns
# Out:
# Index([                          'index',                         'country',
#                          ('country', ''),                      ('year', ''),
#          ('tweets_positive_sent', 'sum'), ('tweets_positive_sent', 'count'),
#              ('tweets_political', 'sum'),     ('tweets_political', 'count'),
#                         ('likes', 'sum'),                ('likes', 'count'),
#                      ('retweets', 'sum'),             ('retweets', 'count'),
#                           'Alpha-3 code'],
#       dtype='object')

# %%
columns_stats = ["tweets_positive_sent", "tweets_political"]
junk = junk[columns_stats].agg(['sum','count'])
# Out:
# Canceled future for execute_request message before replies were done
# Le Kernel s’est bloqué lors de l’exécution du code dans la cellule active ou une cellule précédente. Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec. Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations. Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %% [markdown]
# ## Creation of final dataset

# %%
# Load Trade data
trade = pd.read_csv(os.path.join(path_to_data, trade_filenae))
trade.head()

# %%
# Keep only Chinese exports
trade = trade[trade['country']=='China']

# %%
# Load gdp data
gdp1 = pd.read_csv(os.path.join(path_to_data, gdp_filename_1))
gdp1.head()

# %%
# Load gdp data
gdp2 = pd.read_csv(os.path.join(path_to_data, gdp_filename_2))
gdp2.head()

# %%
# Load pop data
pop = pd.read_csv(os.path.join(path_to_data, population_filename))
pop.head()

# %%
# Load Gravity data
gravity = pd.read_stata(os.path.join(path_to_data, gravity_filename))
gravity.head()
